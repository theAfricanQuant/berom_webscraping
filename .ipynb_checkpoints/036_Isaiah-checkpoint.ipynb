# %%
from berom_scraper import *

base_url = "https://scriptureearth.org/data/bom/sab/bom/bom-23-ISA-{}.html" 

for i in range(1, 67):
    url = base_url.format(str(i).zfill(3))
    
    
    scraper = WebScraper(url, 'berom')
    txt = scraper.soup
    chpt_name = scraper.chapter
    attribs = ('ms', 'mt', 'sp', 's')
    scraper.clean_div(attribs)
    scraper.clean_subdiv('div', 'm', 'c-drop')
    scraper.clean_text()
    scraper.save_json()
# Out:
# JSON data saved to: berom\Yɛshaya_1.json
# JSON data saved to: berom\Yɛshaya_2.json
# JSON data saved to: berom\Yɛshaya_3.json
# JSON data saved to: berom\Yɛshaya_4.json
# JSON data saved to: berom\Yɛshaya_5.json
# JSON data saved to: berom\Yɛshaya_6.json
# JSON data saved to: berom\Yɛshaya_7.json
# JSON data saved to: berom\Yɛshaya_8.json
# JSON data saved to: berom\Yɛshaya_9.json
# JSON data saved to: berom\Yɛshaya_10.json
# JSON data saved to: berom\Yɛshaya_11.json
# JSON data saved to: berom\Yɛshaya_12.json
# JSON data saved to: berom\Yɛshaya_13.json
# JSON data saved to: berom\Yɛshaya_14.json
# JSON data saved to: berom\Yɛshaya_15.json
# JSON data saved to: berom\Yɛshaya_16.json
# JSON data saved to: berom\Yɛshaya_17.json
# JSON data saved to: berom\Yɛshaya_18.json
# JSON data saved to: berom\Yɛshaya_19.json
# JSON data saved to: berom\Yɛshaya_20.json
# JSON data saved to: berom\Yɛshaya_21.json
# JSON data saved to: berom\Yɛshaya_22.json
# JSON data saved to: berom\Yɛshaya_23.json
# JSON data saved to: berom\Yɛshaya_24.json
# JSON data saved to: berom\Yɛshaya_25.json
# JSON data saved to: berom\Yɛshaya_26.json
# JSON data saved to: berom\Yɛshaya_27.json
# JSON data saved to: berom\Yɛshaya_28.json
# JSON data saved to: berom\Yɛshaya_29.json
# JSON data saved to: berom\Yɛshaya_30.json
# JSON data saved to: berom\Yɛshaya_31.json
# JSON data saved to: berom\Yɛshaya_32.json
# JSON data saved to: berom\Yɛshaya_33.json
# JSON data saved to: berom\Yɛshaya_34.json
# JSON data saved to: berom\Yɛshaya_35.json
# JSON data saved to: berom\Yɛshaya_36.json
# JSON data saved to: berom\Yɛshaya_37.json
# JSON data saved to: berom\Yɛshaya_38.json
# JSON data saved to: berom\Yɛshaya_39.json
# JSON data saved to: berom\Yɛshaya_40.json
# JSON data saved to: berom\Yɛshaya_41.json
# JSON data saved to: berom\Yɛshaya_42.json
# JSON data saved to: berom\Yɛshaya_43.json
# JSON data saved to: berom\Yɛshaya_44.json
# JSON data saved to: berom\Yɛshaya_45.json
# JSON data saved to: berom\Yɛshaya_46.json
# JSON data saved to: berom\Yɛshaya_47.json
# JSON data saved to: berom\Yɛshaya_48.json
# JSON data saved to: berom\Yɛshaya_49.json
# JSON data saved to: berom\Yɛshaya_50.json
# JSON data saved to: berom\Yɛshaya_51.json
# JSON data saved to: berom\Yɛshaya_52.json
# JSON data saved to: berom\Yɛshaya_53.json
# JSON data saved to: berom\Yɛshaya_54.json
# JSON data saved to: berom\Yɛshaya_55.json
# JSON data saved to: berom\Yɛshaya_56.json
# JSON data saved to: berom\Yɛshaya_57.json
# JSON data saved to: berom\Yɛshaya_58.json
# JSON data saved to: berom\Yɛshaya_59.json
# JSON data saved to: berom\Yɛshaya_60.json
# JSON data saved to: berom\Yɛshaya_61.json
# JSON data saved to: berom\Yɛshaya_62.json
# JSON data saved to: berom\Yɛshaya_63.json
# JSON data saved to: berom\Yɛshaya_64.json
# JSON data saved to: berom\Yɛshaya_65.json
# JSON data saved to: berom\Yɛshaya_66.json
