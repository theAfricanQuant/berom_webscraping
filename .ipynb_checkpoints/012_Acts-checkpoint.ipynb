# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
from pathlib import Path
import json


class WebScraper:
    def __init__(self, url: str, folder: str):
        self.url = url
        self.folder = folder
        self.soup = self.scrape()
        self.chapter = self.soup.find('title').text.replace(" ", "_")

    def scrape(self):
        req = Request(self.url, headers={'User-Agent': 'Mozilla/5.0'})
        url_content = urlopen(req).read()
        return BeautifulSoup(url_content, "lxml")
    
    def clean_div(self, *attribs):
        for attrib in attribs:
            div_tags = self.soup.find_all('div', class_=attrib)
            for div in div_tags:
                div.extract()
    
    def clean_subdiv(self, div, att, sub_att):
        parent_div = self.soup.find(div, class_=att) 

        if parent_div:
            subdivision_div = parent_div.find(div, class_=sub_att)  
            if subdivision_div:
                subdivision_div.extract()

    def clean_text(self):
        
        self.raw = (self.soup.text
               .split('©')[0]
               .split('>')[-1]
               .strip()
               )
       

    def save_json(self):
        
        # Specify the filename
        json_name = f'{self.chapter}.json'   

        # Create the folder if it doesn't exist
        Path(self.folder).mkdir(parents=True, exist_ok=True)

        # Construct the file path
        json_path = Path(self.folder) / json_name

        data = {}
        matches = re.findall(r'(\d+)\s+([\s\S]*?)(?=\d|$)', self.raw)
        for match in matches:
            key = match[0]
            value = match[1].strip()
            data[key] = value

        with open(json_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False)

        print("JSON data saved to:", json_path)

        
        
# Example usage:
url = "https://scriptureearth.org/data/bom/sab/bom/bom-16-NEH-013.html"
scraper = WebScraper(url, 'berom')
txt = scraper.soup
chpt_name = scraper.chapter

# %%
attribs = ('ms', 'mt', 'sp')
scraper.clean_div(attribs)
scraper.clean_subdiv('div', 'm', 'c-drop')
scraper.clean_text()
scraper.save_json()
print(scraper.raw)
# Out:
# JSON data saved to: berom/Nɛhɛmiya_13.json
# Ba kang yére dyuk detu
#
#  1 E jeng o bá sè basa a BeIsrayɛl Bwok-basâ Mose na gbɔng fwɔ, bá wul kwɔn de ba jɛk ɛ wɔgɔ, be kwon tik WoAmɔn kɛ WoMowap hwak a wuna hɛ na bemât Dagwi wɛt. 2 Ba jɛk ano, yaga BeAmɔn na BeMowap bá kana nɔ̂ng BeIsrayɛl pyɛ̂ re kɛ nshî sɔ wɛt, jeng de yɛn á sè kyè yi e vwêl Misra. Ko BeMowap bá nɔ̂ng Balaam, dyām yaga na a mok a BeIsrayɛl gawey. Ko Dagwi mot á tɛ̀ gawey o ha tɛ́ ɛ a yɛn nerat. 3 Jeng de BeIsrayɛl bá wok bása mo, ba vɛ̌ kang mwa bemât yére dyuk yi na yɛn.
# Pyɛ́ ryat de Nɛhɛmiya a ra
# 4 Ɛliyaship, piris de a vɔk reto e ra begban Gbɔng Duk Re Fongol, a ga ros a sè sɛ̀ pang na Tobiya, 5 ko a simo a yɛ na a ra fwom na duk rwey o hwak de ba tik wɛ yaga tikîs nɔrɔ̂ pyɛ̂ yeneng, na pyɛ̂ nesang hyɔɔlɔl, na pyɛ́ detidetu de be ra mɛ fwom e Gbɔng Duk o, na pyɛ̂ nɔrɔ de be nɔngɔs yaga bepiris tanga pyɔlɔ̂ pyɛ̂ yeneng, na yê nshî anap, na yê něy pwat de ba nɔngɔ̂s BeLevi, na bemât lwɛlɛ tanga vê gyêng ri Gbɔng Duk o. 6 Ko di, jeng de pyɛ́ yemo yá sè tē, má sè e Yɛrusalɛm wɛt, yaga e ji shey hê kuru batat na hɛ ba (32) de Artasɛrsɛs á sè gbɔng gwɔ̀m Babilɔn,a ma kana toyo na me wɔ̀ ha a yɛ pyɛ́ de ma ga ra. Ko e bamâ jeng, a to simo a me, 7 na me toyo vɔk e Yɛrusalɛm. Ras de ma toyo, ba ha a me pyɛ vyes de Ɛliyaship a ga ra, a ga simo a Tobiya, na a ra fwom na duk hwak e lalâ Gbɔng Duk Re Fongol! 8 A yang me furutut, ko ma wɔ̀ paa, me bomos a Tobiya pyɛ́ mɛ mo mwa e jey. 9 Ma nɔng nu be fung duk o, na be to toyo na nedok nekyɔrɔ̂k Gbɔng Duk o, ba to tik e ji wɛ, mwa na nɔrɔ̂ pyɛ̂ yeneng tanga pyɛ̂ nesang hyɔɔlɔl.
# 10 Ano arɔng, ma wok, bemât lwɛlɛ̂ Gbɔng Duk Re Fongol tanga BeLevi behak ba ga hala Yɛrusalɛm. Yɛn a tòros hɛn vɔk e hiri mɛn, yaga ba nɔngɔs hɛn pyɛ̂ re de ya vɛ̀sɛ a yɛn wɛt. 11 Yaga ano, ma gyong bemât nuyêl tom o, yaga yɛn a kyini Gbɔng Duk Re Fongol. Ko ma to toyo na BeLevi tanga bemât lwɛlɛ mo vey e Gbɔng Duk o, na yɛn a to re nuyel na tom mɛn. 12 Ano kwong, BeYuda mwa ba to hwo vɛ̀sɛ na pyɔlɔ mɛn e begban Gbɔng Duk o. Yɛn a vɛ̀sɛ na pyɔlɔ̂ pyɛ̂ yeneng na nshî anap tanga něy pwat. 13 Ma tɛ̀ bemat, na be vɔk reto e ra begban o, yɛn vɛ à Shɛlɛmiya, piris, na Zadɔk, kaan-tɔ̂k Badu Dagwi, tanga Pedaya WoLevi. Ko ma tɛ̀ Hanan Zakur Mataniya a sè mwât sɛlɛ mɛn. Ba tɔk yɛn a sé bemât tsak o, yaga ano, ma tɔk yɛn ê gas a bemɛn bemât fwom pyɛ́ de be nɔngɔs e gwong de gwa sé mwin.
# 14 À Dagwi hom, bare na pyɛ́ yemo mwa de ma ga ra yaga Gbɔng Duk mō, tanga yaga rê fongol e ji wɛ!
# 15 E jeng yane, ma di bemat e vwêl Yuda ba sè farang nèy anap, na be piri nshi mo Tuk Shábat. Ko behak ba sè tɛ̀sɛ a bemadung mɛn pyɛ̂ yeneng, na nshî anap, na nèy anap, na nèy regwi tanga bwang pyɛ́ cak, na be kyè mɛ vɔk e Yɛrusalɛm. Ko ma tusa hɛn, yɛn a kwon row pyɛ cak Tuk Shábat wɛt. 16 Bemât gbɔng pomô Tur behak arɔng de ba sangal e Yɛrusalɛm bá vey na betɔk na nediri nedôk pyɛ̂ rɛsɛl e repomo, yaga na be rɛsɛl a BeYuda yɛ Tuk Shábat. 17 Ma gyong bemât nuyêl BeYuda, ma yang ɛn, “Di in yerê neves de yin a sé ra! Yin a sé lashe Tuk Shábat. 18 Pyɛ́ ma yemo de yá tɛ̀ Dagwi á tabak bedabeda min jeng de á tɛ̀ be wey na repomo remo. Ko mwa ano, yin a sé gwɛ̌ shôm Dagwi e ra yin, yaga yin e lashe Tuk Shábat.”
# 19 Yaga ano, ma nɔng nu, kahɛ Tuk Shábat, be bangas ri rùhup gbɔng pomo jeng de gwi gwa sé kyè wɔ̀ hwo ɛ.b Ko be to wuma vɛ wɛt sɛ̌ Tuk Shábat ha kwey. Ma tɛ̀ bemat hom behak e rùhup o, na be dul bemat nà yel na pyɛ cak e ji repomo Tuk Shábat. 20 E bama mo, zang hining kɛ ba ayi, bejik de be rɛsɛl nedirî nedok ba pɔlɔs e bamâ jwâ-pomo tuk tungun fwom. 21 Ma tusa hɛn, ma yang ɛn, “A sé zɔng-reng de yin e pɔlɔs e hane, na yin gyeng gasi. Tsút! Ka sede yin a to ba gwɛ̌, ko ma rɔda tɛ̀ be vos in.” Yi e jeng yane, yɛn a to vɛ̀sɛ Tuk Shábat wɛt. 22 Ma nɔ̂ng BeLevi nu, be tɛ̀ bato mɛn haalal, na yɛn a kyese gyengês rùhup o, yaga na be gyenges Tuk Shábat jɛrɛ.
# À Dagwi, bare na me, yaga pyɛ́ yemo arɔng. Tosho reyɔm hom, yaga ma tɔk, tɛ̂ yey mō ha sé rey o.
# 23 E jeng yane arɔng, ma di bemat e ji BeYuda de ba ra wenêng beha yi e Ashdot tanga vê BeAmɔn na BeMowap. 24 Rebit nèy mɛn ne ha lêm Ashdot kɛ relem o rehak, ko ne tɔk ha na lem mot wɛt. 25 Ma gyong bemat o sizɔng, ma mok a yɛn gawey, ma dak behak, ko ma luyu a yɛn setot. E bama mo, ma tɛ̀ ɛn, be sira na rezâ Dagwi wɔgɔ, kɛ yɛn kɛ nèy mɛn bê sang to ragas weneng e tē mɛn na yére dyuk wɛt. 26 Ma to yang ɛn ngan, “Yin a tɔk wɛt a? E behâ yére dyuk de bá tɛ̀ Gbɔng Gwɔ̀m Sɔlɔmɔn a ra banɛn. Di in, yɛ á sè mwat de á dal bwang begbɔng begwɔ̀m yére jey mwa na nerey. Dagwi á tɛ̀ yey na yɛ, ko a tɛ̀ ɛ a sè gbɔng gwɔ̀m e ra BeIsrayɛl mwa, ko mwa ano, á ra renɛn remo. 27 Ko sɛ̌ wot ê raa begwong min a? Ka wot a ra wenêng behâ yére dyuk, ko wot a kyɛ́ ot nà gyeng hâ Dagwi mot!”
# 28 Yɔyada a sé hwêy Ɛliyaship, darwêy bepiris, ko hak e ji nèy Yɔyada mo a ra wenêng hwông Sanbalat yi e repomô Bet-Hɔrɔn. Yaga ano, ma vɔk ma ro Yɔyada mo yi e Yɛrusalɛm.
# 29 À Dagwi, bare na gwong de bemat vane ba lashe fwôm piris, ko yɛn a to lashe wuna-na-sira de hwà kana ra na bepiris mwa na BeLevi.
# 30 Ma tɛ̀ bemat o be kang ɛn yi e kayɛ pyɛ de ya sé ye yére dyuk, yi ano yɛn a tɛ́ ɛn haalal. Ma yong badu yaga bepiris tanga BeLevi, yaga na kawɛ e ji mɛn a tɔk tyɛng fwom mɛ. 31 Ma to yong ɛ, na be vɛ̀sɛ na cɔ́gɔt de be rangas mɛ nɔrɔ̂ yas e jeng de ya jamas ɛ, ko na bemat o be vɛ̀sɛ na nenɔrɔ mɛn ne pyɛ̂ yeneng yê mɛsɛng tanga ne nèy cɔ́gɔt ne mɛsɛng arɔng.
# À Dagwi, bare na pyɛ́ yemo mwa, na hwo nɔng me pyɔlɔ hom e ra yɛ.
