# %%
from berom_scraper import *

base_url = "https://scriptureearth.org/data/bom/sab/bom/bom-19-PSA-{}.html" 

for i in range(1, 151):
    url = base_url.format(str(i).zfill(3))
    
    
    scraper = WebScraper(url, 'berom')
    txt = scraper.soup
    chpt_name = scraper.chapter
    attribs = ('ms', 'mt', 'sp', 's')
    scraper.clean_div(attribs)
    scraper.clean_subdiv('div', 'm', 'c-drop')
    scraper.clean_text()
    scraper.save_json()
# Out:
# JSON data saved to: berom\Lɛlɛ_1.json
# JSON data saved to: berom\Lɛlɛ_2.json
# JSON data saved to: berom\Lɛlɛ_3.json
# JSON data saved to: berom\Lɛlɛ_4.json
# JSON data saved to: berom\Lɛlɛ_5.json
# JSON data saved to: berom\Lɛlɛ_6.json
# JSON data saved to: berom\Lɛlɛ_7.json
# JSON data saved to: berom\Lɛlɛ_8.json
# JSON data saved to: berom\Lɛlɛ_9.json
# JSON data saved to: berom\Lɛlɛ_10.json
# JSON data saved to: berom\Lɛlɛ_11.json
# JSON data saved to: berom\Lɛlɛ_12.json
# JSON data saved to: berom\Lɛlɛ_13.json
# JSON data saved to: berom\Lɛlɛ_14.json
# JSON data saved to: berom\Lɛlɛ_15.json
# JSON data saved to: berom\Lɛlɛ_16.json
# JSON data saved to: berom\Lɛlɛ_17.json
# JSON data saved to: berom\Lɛlɛ_18.json
# JSON data saved to: berom\Lɛlɛ_19.json
# JSON data saved to: berom\Lɛlɛ_20.json
# JSON data saved to: berom\Lɛlɛ_21.json
# JSON data saved to: berom\Lɛlɛ_22.json
# JSON data saved to: berom\Lɛlɛ_23.json
# JSON data saved to: berom\Lɛlɛ_24.json
# JSON data saved to: berom\Lɛlɛ_25.json
# JSON data saved to: berom\Lɛlɛ_26.json
# JSON data saved to: berom\Lɛlɛ_27.json
# JSON data saved to: berom\Lɛlɛ_28.json
# JSON data saved to: berom\Lɛlɛ_29.json
# JSON data saved to: berom\Lɛlɛ_30.json
# JSON data saved to: berom\Lɛlɛ_31.json
# JSON data saved to: berom\Lɛlɛ_32.json
# JSON data saved to: berom\Lɛlɛ_33.json
# JSON data saved to: berom\Lɛlɛ_34.json
# JSON data saved to: berom\Lɛlɛ_35.json
# JSON data saved to: berom\Lɛlɛ_36.json
# JSON data saved to: berom\Lɛlɛ_37.json
# JSON data saved to: berom\Lɛlɛ_38.json
# JSON data saved to: berom\Lɛlɛ_39.json
# JSON data saved to: berom\Lɛlɛ_40.json
# JSON data saved to: berom\Lɛlɛ_41.json
# JSON data saved to: berom\Lɛlɛ_42.json
# JSON data saved to: berom\Lɛlɛ_43.json
# JSON data saved to: berom\Lɛlɛ_44.json
# JSON data saved to: berom\Lɛlɛ_45.json
# JSON data saved to: berom\Lɛlɛ_46.json
# JSON data saved to: berom\Lɛlɛ_47.json
# JSON data saved to: berom\Lɛlɛ_48.json
# JSON data saved to: berom\Lɛlɛ_49.json
# JSON data saved to: berom\Lɛlɛ_50.json
# JSON data saved to: berom\Lɛlɛ_51.json
# JSON data saved to: berom\Lɛlɛ_52.json
# JSON data saved to: berom\Lɛlɛ_53.json
# JSON data saved to: berom\Lɛlɛ_54.json
# JSON data saved to: berom\Lɛlɛ_55.json
# JSON data saved to: berom\Lɛlɛ_56.json
# JSON data saved to: berom\Lɛlɛ_57.json
# JSON data saved to: berom\Lɛlɛ_58.json
# JSON data saved to: berom\Lɛlɛ_59.json
# JSON data saved to: berom\Lɛlɛ_60.json
# JSON data saved to: berom\Lɛlɛ_61.json
# JSON data saved to: berom\Lɛlɛ_62.json
# JSON data saved to: berom\Lɛlɛ_63.json
# JSON data saved to: berom\Lɛlɛ_64.json
# JSON data saved to: berom\Lɛlɛ_65.json
# JSON data saved to: berom\Lɛlɛ_66.json
# JSON data saved to: berom\Lɛlɛ_67.json
# JSON data saved to: berom\Lɛlɛ_68.json
# JSON data saved to: berom\Lɛlɛ_69.json
# JSON data saved to: berom\Lɛlɛ_70.json
# JSON data saved to: berom\Lɛlɛ_71.json
# JSON data saved to: berom\Lɛlɛ_72.json
# JSON data saved to: berom\Lɛlɛ_73.json
# JSON data saved to: berom\Lɛlɛ_74.json
# JSON data saved to: berom\Lɛlɛ_75.json
# JSON data saved to: berom\Lɛlɛ_76.json
# JSON data saved to: berom\Lɛlɛ_77.json
# JSON data saved to: berom\Lɛlɛ_78.json
# JSON data saved to: berom\Lɛlɛ_79.json
# JSON data saved to: berom\Lɛlɛ_80.json
# JSON data saved to: berom\Lɛlɛ_81.json
# JSON data saved to: berom\Lɛlɛ_82.json
# JSON data saved to: berom\Lɛlɛ_83.json
# JSON data saved to: berom\Lɛlɛ_84.json
# JSON data saved to: berom\Lɛlɛ_85.json
# JSON data saved to: berom\Lɛlɛ_86.json
# JSON data saved to: berom\Lɛlɛ_87.json
# JSON data saved to: berom\Lɛlɛ_88.json
# JSON data saved to: berom\Lɛlɛ_89.json
# JSON data saved to: berom\Lɛlɛ_90.json
# JSON data saved to: berom\Lɛlɛ_91.json
# JSON data saved to: berom\Lɛlɛ_92.json
# JSON data saved to: berom\Lɛlɛ_93.json
# JSON data saved to: berom\Lɛlɛ_94.json
# JSON data saved to: berom\Lɛlɛ_95.json
# JSON data saved to: berom\Lɛlɛ_96.json
# JSON data saved to: berom\Lɛlɛ_97.json
# JSON data saved to: berom\Lɛlɛ_98.json
# JSON data saved to: berom\Lɛlɛ_99.json
# JSON data saved to: berom\Lɛlɛ_100.json
# JSON data saved to: berom\Lɛlɛ_101.json
# JSON data saved to: berom\Lɛlɛ_102.json
# JSON data saved to: berom\Lɛlɛ_103.json
# JSON data saved to: berom\Lɛlɛ_104.json
# JSON data saved to: berom\Lɛlɛ_105.json
# JSON data saved to: berom\Lɛlɛ_106.json
# JSON data saved to: berom\Lɛlɛ_107.json
# JSON data saved to: berom\Lɛlɛ_108.json
# JSON data saved to: berom\Lɛlɛ_109.json
# JSON data saved to: berom\Lɛlɛ_110.json
# JSON data saved to: berom\Lɛlɛ_111.json
# JSON data saved to: berom\Lɛlɛ_112.json
# JSON data saved to: berom\Lɛlɛ_113.json
# JSON data saved to: berom\Lɛlɛ_114.json
# JSON data saved to: berom\Lɛlɛ_115.json
# JSON data saved to: berom\Lɛlɛ_116.json
# JSON data saved to: berom\Lɛlɛ_117.json
# JSON data saved to: berom\Lɛlɛ_118.json
# JSON data saved to: berom\Lɛlɛ_119.json
# JSON data saved to: berom\Lɛlɛ_120.json
# JSON data saved to: berom\Lɛlɛ_121.json
# JSON data saved to: berom\Lɛlɛ_122.json
# JSON data saved to: berom\Lɛlɛ_123.json
# JSON data saved to: berom\Lɛlɛ_124.json
# JSON data saved to: berom\Lɛlɛ_125.json
# JSON data saved to: berom\Lɛlɛ_126.json
# JSON data saved to: berom\Lɛlɛ_127.json
# JSON data saved to: berom\Lɛlɛ_128.json
# JSON data saved to: berom\Lɛlɛ_129.json
# JSON data saved to: berom\Lɛlɛ_130.json
# JSON data saved to: berom\Lɛlɛ_131.json
# JSON data saved to: berom\Lɛlɛ_132.json
# JSON data saved to: berom\Lɛlɛ_133.json
# JSON data saved to: berom\Lɛlɛ_134.json
# JSON data saved to: berom\Lɛlɛ_135.json
# JSON data saved to: berom\Lɛlɛ_136.json
# JSON data saved to: berom\Lɛlɛ_137.json
# JSON data saved to: berom\Lɛlɛ_138.json
# JSON data saved to: berom\Lɛlɛ_139.json
# JSON data saved to: berom\Lɛlɛ_140.json
# JSON data saved to: berom\Lɛlɛ_141.json
# JSON data saved to: berom\Lɛlɛ_142.json
# JSON data saved to: berom\Lɛlɛ_143.json
# JSON data saved to: berom\Lɛlɛ_144.json
# JSON data saved to: berom\Lɛlɛ_145.json
# JSON data saved to: berom\Lɛlɛ_146.json
# JSON data saved to: berom\Lɛlɛ_147.json
# JSON data saved to: berom\Lɛlɛ_148.json
# JSON data saved to: berom\Lɛlɛ_149.json
# JSON data saved to: berom\Lɛlɛ_150.json
